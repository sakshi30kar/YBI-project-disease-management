# %%
#import library
import pandas as pd

# %%
#import data
disease = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/MultipleDiseasePrediction.csv')

# %%
#info
disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Columns: 133 entries, itching to prognosis
# dtypes: int64(132), object(1)
# memory usage: 5.0+ MB

# %%
#summary statistcs
disease.describe()
# Out:
#            itching    skin_rash  nodal_skin_eruptions  continuous_sneezing  \
# count  4920.000000  4920.000000           4920.000000          4920.000000
# mean      0.137805     0.159756              0.021951             0.045122
# std       0.344730     0.366417              0.146539             0.207593
# min       0.000000     0.000000              0.000000             0.000000
# 25%       0.000000     0.000000              0.000000             0.000000
# 50%       0.000000     0.000000              0.000000             0.000000
# 75%       0.000000     0.000000              0.000000             0.000000
# max       1.000000     1.000000              1.000000             1.000000
#
#          shivering       chills   joint_pain  stomach_pain      acidity  \
# count  4920.000000  4920.000000  4920.000000   4920.000000  4920.000000
# mean      0.021951     0.162195     0.139024      0.045122     0.045122
# std       0.146539     0.368667     0.346007      0.207593     0.207593
# ...

# %%
# check for missing value
disease.isnull().sum()
# Out:
# itching                 0
# skin_rash               0
# nodal_skin_eruptions    0
# continuous_sneezing     0
# shivering               0
#                        ..
# inflammatory_nails      0
# blister                 0
# red_sore_around_nose    0
# yellow_crust_ooze       0
# prognosis               0
# Length: 133, dtype: int64

# %%
# check for categories
disease.nunique()
# Out:
# itching                  2
# skin_rash                2
# nodal_skin_eruptions     2
# continuous_sneezing      2
# shivering                2
#                         ..
# inflammatory_nails       2
# blister                  2
# red_sore_around_nose     2
# yellow_crust_ooze        2
# prognosis               41
# Length: 133, dtype: int64

# %%
# correlation
disease.corr()
# Out:
#                        itching  skin_rash  nodal_skin_eruptions  \
# itching               1.000000   0.318158              0.326439
# skin_rash             0.318158   1.000000              0.298143
# nodal_skin_eruptions  0.326439   0.298143              1.000000
# continuous_sneezing  -0.086906  -0.094786             -0.032566
# shivering            -0.059893  -0.065324             -0.022444
# ...                        ...        ...                   ...
# small_dents_in_nails -0.061573   0.331087             -0.023073
# inflammatory_nails   -0.061573   0.331087             -0.023073
# blister              -0.061573   0.331087             -0.023073
# red_sore_around_nose -0.061573   0.331087             -0.023073
# yellow_crust_ooze    -0.061573   0.331087             -0.023073
#
#                       continuous_sneezing  shivering    chills  joint_pain  \
# itching                         -0.086906  -0.059893 -0.175905   -0.160650
# ...

# %%
#column index
disease.columns
# Out:
# Index(['itching', 'skin_rash', 'nodal_skin_eruptions', 'continuous_sneezing',
#        'shivering', 'chills', 'joint_pain', 'stomach_pain', 'acidity',
#        'ulcers_on_tongue',
#        ...
#        'blackheads', 'scurring', 'skin_peeling', 'silver_like_dusting',
#        'small_dents_in_nails', 'inflammatory_nails', 'blister',
#        'red_sore_around_nose', 'yellow_crust_ooze', 'prognosis'],
#       dtype='object', length=133)

# %%
#shape
disease.shape
# Out:
# (4920, 133)

# %%
# values for y and X
y=disease['itching']
X=disease[['skin_rash', 'nodal_skin_eruptions', 'continuous_sneezing','shivering', 'chills','blackheads', 'scurring', 'skin_peeling', 'silver_like_dusting', 'joint_pain', 'stomach_pain', 'acidity',
'ulcers_on_tongue','small_dents_in_nails', 'inflammatory_nails', 'blister','red_sore_around_nose', 'yellow_crust_ooze', 'prognosis']]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   skin_rash             4920 non-null   int64
#  1   nodal_skin_eruptions  4920 non-null   int64
#  2   continuous_sneezing   4920 non-null   int64
#  3   shivering             4920 non-null   int64
#  4   chills                4920 non-null   int64
#  5   blackheads            4920 non-null   int64
#  6   scurring              4920 non-null   int64
#  7   skin_peeling          4920 non-null   int64
#  8   silver_like_dusting   4920 non-null   int64
#  9   joint_pain            4920 non-null   int64
#  10  stomach_pain          4920 non-null   int64
#  11  acidity               4920 non-null   int64
#  12  ulcers_on_tongue      4920 non-null   int64
#  13  small_dents_in_nails  4920 non-null   int64
#  14  inflammatory_nails    4920 non-null   int64
# ...

# %%
# visualize pairplot
from IPython.display import Image
import seaborn as sns
import matplotlib.pyplot as plt
df = disease[['itching', 'skin_rash', 'nodal_skin_eruptions', 'continuous_sneezing',
'shivering', 'chills']]
sns_plot = sns.pairplot (df,diag_kind='kde',height=2.0)
sns_plot.savefig("pairplot.png")
plt.clf()
Image(filename='pairplot.png')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train ,y_test = train_test_split(X,y,train_size = 0.7, random_state=2529 )

# %%
# verify shape
X_train.shape, X_test.shape, y_train.shape ,y_test.shape
# Out:
# ((3444, 19), (1476, 19), (3444,), (1476,))

# %%
# select model
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
# train model
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15604\604127000.py in <module>
#       1 # train model
# ----> 2 model.fit(X_train,y_train)
#
# NameError: name 'model' is not defined
